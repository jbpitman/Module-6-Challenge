# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.(6.1.5)
cities = []

# %%
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=975ffdad65e7a63bedc91250a78d958c

# %%
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
# Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
# Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
   
#Append the city information into city_data list.
        city_data.append({"City": city.title(), "Lat": city_lat,"Lng": city_lng,"Max Temp": city_max_temp,
                          "Humidity": city_humidity,"Cloudiness": city_clouds,"Wind Speed": city_wind,})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | ishigaki
# Processing Record 3 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | jhalu
# Processing Record 6 of Set 1 | pisco
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | sitka
# Processing Record 10 of Set 1 | jijiang
# Processing Record 11 of Set 1 | fairbanks
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | henties bay
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | beidao
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | varkaus
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | mount gambier
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | rock sound
# Processing Record 26 of Set 1 | morti
# City not found. Skipping...
# Processing Record 27 of Set 1 | beyneu
# Processing Record 28 of Set 1 | san ramon
# Processing Record 29 of Set 1 | bonthe
# Processing Record 30 of Set 1 | acapulco
# Processing Record 31 of Set 1 | naze
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | soligalich
# Processing Record 34 of Set 1 | sabang
# Processing Record 35 of Set 1 | hokitika
# Processing Record 36 of Set 1 | uspenka
# Processing Record 37 of Set 1 | luwuk
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | nouadhibou
# Processing Record 40 of Set 1 | liberal
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | mubende
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | quetzaltepec
# City not found. Skipping...
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | waslala
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | sao joaquim
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | mabai
# Processing Record 13 of Set 2 | hambantota
# Processing Record 14 of Set 2 | broken hill
# Processing Record 15 of Set 2 | lipnita
# Processing Record 16 of Set 2 | muisne
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | bambanglipuro
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 2 | rundu
# Processing Record 21 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | huancabamba
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | matara
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | dwarka
# Processing Record 28 of Set 2 | aswan
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | hwange
# Processing Record 31 of Set 2 | ust-omchug
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | berlevag
# Processing Record 34 of Set 2 | oranjemund
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | saint-pierre
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | sakakah
# Processing Record 39 of Set 2 | iglesias
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | dicabisagan
# Processing Record 44 of Set 2 | kabo
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | deputatskiy
# Processing Record 47 of Set 2 | pacific grove
# Processing Record 48 of Set 2 | grindavik
# Processing Record 49 of Set 2 | te anau
# Processing Record 50 of Set 2 | ancud
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | kazanskoye
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | ileza
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | oda
# Processing Record 7 of Set 3 | morag
# Processing Record 8 of Set 3 | guanica
# Processing Record 9 of Set 3 | cockburn town
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | puquio
# Processing Record 12 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 3 | neepawa
# Processing Record 14 of Set 3 | sol-iletsk
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | yulara
# Processing Record 18 of Set 3 | berck
# Processing Record 19 of Set 3 | mehamn
# Processing Record 20 of Set 3 | palu
# Processing Record 21 of Set 3 | dickinson
# Processing Record 22 of Set 3 | imbituba
# Processing Record 23 of Set 3 | yeppoon
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | novikovo
# Processing Record 26 of Set 3 | narsaq
# Processing Record 27 of Set 3 | awbari
# Processing Record 28 of Set 3 | tarnos
# Processing Record 29 of Set 3 | ourossogui
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | anito
# Processing Record 32 of Set 3 | paamiut
# Processing Record 33 of Set 3 | flin flon
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | haysville
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | surt
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | lompoc
# Processing Record 40 of Set 3 | ostrovnoy
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | tautira
# Processing Record 43 of Set 3 | ust-kuyga
# Processing Record 44 of Set 3 | butaritari
# Processing Record 45 of Set 3 | axim
# Processing Record 46 of Set 3 | arrecife
# Processing Record 47 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | yima
# Processing Record 50 of Set 3 | gravdal
# Processing Record 1 of Set 4 | sri aman
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | gotsu
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | nanyamba
# Processing Record 7 of Set 4 | fernley
# Processing Record 8 of Set 4 | picui
# Processing Record 9 of Set 4 | nantucket
# Processing Record 10 of Set 4 | datong
# Processing Record 11 of Set 4 | chimore
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | nome
# Processing Record 14 of Set 4 | noumea
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | mirabad
# Processing Record 17 of Set 4 | samarai
# Processing Record 18 of Set 4 | antofagasta
# Processing Record 19 of Set 4 | tsumeb
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | ulladulla
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | galesong
# Processing Record 24 of Set 4 | namtsy
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | la palma
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | leshukonskoye
# Processing Record 30 of Set 4 | atuona
# Processing Record 31 of Set 4 | vao
# Processing Record 32 of Set 4 | kirovskiy
# Processing Record 33 of Set 4 | sorland
# Processing Record 34 of Set 4 | saldanha
# Processing Record 35 of Set 4 | wagar
# Processing Record 36 of Set 4 | birin
# Processing Record 37 of Set 4 | alice springs
# Processing Record 38 of Set 4 | esso
# Processing Record 39 of Set 4 | storsteinnes
# Processing Record 40 of Set 4 | poum
# Processing Record 41 of Set 4 | kosai
# Processing Record 42 of Set 4 | nelson bay
# Processing Record 43 of Set 4 | palasa
# Processing Record 44 of Set 4 | beringovskiy
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | angoram
# Processing Record 47 of Set 4 | ghanzi
# Processing Record 48 of Set 4 | berbera
# Processing Record 49 of Set 4 | shizuishan
# Processing Record 50 of Set 4 | westport
# Processing Record 1 of Set 5 | kilinochchi
# Processing Record 2 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | cedar city
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | banda aceh
# Processing Record 6 of Set 5 | fort morgan
# Processing Record 7 of Set 5 | botwood
# Processing Record 8 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | tura
# Processing Record 12 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 5 | formosa
# Processing Record 14 of Set 5 | grand gaube
# Processing Record 15 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 16 of Set 5 | novyye burasy
# Processing Record 17 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 5 | etchoropo
# Processing Record 19 of Set 5 | north platte
# Processing Record 20 of Set 5 | lebu
# Processing Record 21 of Set 5 | hovd
# Processing Record 22 of Set 5 | alofi
# Processing Record 23 of Set 5 | saint-leu
# Processing Record 24 of Set 5 | boca do acre
# Processing Record 25 of Set 5 | lubango
# Processing Record 26 of Set 5 | itarema
# Processing Record 27 of Set 5 | vanavara
# Processing Record 28 of Set 5 | trat
# Processing Record 29 of Set 5 | meulaboh
# Processing Record 30 of Set 5 | codrington
# Processing Record 31 of Set 5 | pangnirtung
# Processing Record 32 of Set 5 | san rafael
# Processing Record 33 of Set 5 | kingman
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | villa san giovanni
# Processing Record 36 of Set 5 | coquimbo
# Processing Record 37 of Set 5 | qabis
# City not found. Skipping...
# Processing Record 38 of Set 5 | ferme-neuve
# Processing Record 39 of Set 5 | marolambo
# Processing Record 40 of Set 5 | tevaitoa
# Processing Record 41 of Set 5 | san vicente
# Processing Record 42 of Set 5 | watsa
# Processing Record 43 of Set 5 | guican
# Processing Record 44 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 5 | albury
# Processing Record 46 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 5 | mumford
# Processing Record 48 of Set 5 | krasnoselkup
# Processing Record 49 of Set 5 | hailin
# Processing Record 50 of Set 5 | salym
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | la ronge
# Processing Record 4 of Set 6 | urdoma
# Processing Record 5 of Set 6 | rio gallegos
# Processing Record 6 of Set 6 | frolovo
# Processing Record 7 of Set 6 | baijiantan
# Processing Record 8 of Set 6 | ribeira grande
# Processing Record 9 of Set 6 | tarata
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 6 | rustenburg
# Processing Record 13 of Set 6 | sao jose da coroa grande
# Processing Record 14 of Set 6 | mattru
# Processing Record 15 of Set 6 | yar-sale
# Processing Record 16 of Set 6 | provideniya
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | nabire
# Processing Record 21 of Set 6 | nipawin
# Processing Record 22 of Set 6 | thompson
# Processing Record 23 of Set 6 | sampit
# Processing Record 24 of Set 6 | tuktoyaktuk
# Processing Record 25 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | tigzirt
# Processing Record 27 of Set 6 | tual
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | airai
# Processing Record 30 of Set 6 | eureka
# Processing Record 31 of Set 6 | houma
# Processing Record 32 of Set 6 | vestmanna
# Processing Record 33 of Set 6 | victoria
# Processing Record 34 of Set 6 | am timan
# Processing Record 35 of Set 6 | khilok
# Processing Record 36 of Set 6 | marystown
# Processing Record 37 of Set 6 | bengkulu
# Processing Record 38 of Set 6 | ayni
# Processing Record 39 of Set 6 | havre-saint-pierre
# Processing Record 40 of Set 6 | sorong
# Processing Record 41 of Set 6 | tabou
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | leningradskiy
# Processing Record 44 of Set 6 | melong
# Processing Record 45 of Set 6 | galle
# Processing Record 46 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 6 | ondjiva
# Processing Record 48 of Set 6 | vila velha
# Processing Record 49 of Set 6 | kushmurun
# Processing Record 50 of Set 6 | aqtobe
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | chapais
# Processing Record 3 of Set 7 | denizli
# Processing Record 4 of Set 7 | lasa
# Processing Record 5 of Set 7 | balykshi
# Processing Record 6 of Set 7 | guanaja
# Processing Record 7 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 7 | gualeguay
# Processing Record 9 of Set 7 | santa maria
# Processing Record 10 of Set 7 | pittsfield
# Processing Record 11 of Set 7 | cacoal
# Processing Record 12 of Set 7 | owensboro
# Processing Record 13 of Set 7 | bilma
# Processing Record 14 of Set 7 | japura
# Processing Record 15 of Set 7 | arraial do cabo
# Processing Record 16 of Set 7 | kruisfontein
# Processing Record 17 of Set 7 | luderitz
# Processing Record 18 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 7 | college
# Processing Record 20 of Set 7 | athabasca
# Processing Record 21 of Set 7 | pandan
# Processing Record 22 of Set 7 | komsomolskiy
# Processing Record 23 of Set 7 | ostashkov
# Processing Record 24 of Set 7 | dakar
# Processing Record 25 of Set 7 | capljina
# Processing Record 26 of Set 7 | clyde river
# Processing Record 27 of Set 7 | veinticinco de mayo
# Processing Record 28 of Set 7 | kartuzy
# Processing Record 29 of Set 7 | geraldton
# Processing Record 30 of Set 7 | pyshchug
# Processing Record 31 of Set 7 | guanay
# Processing Record 32 of Set 7 | atambua
# Processing Record 33 of Set 7 | laurinburg
# Processing Record 34 of Set 7 | kralendijk
# Processing Record 35 of Set 7 | saint anthony
# Processing Record 36 of Set 7 | ahuimanu
# Processing Record 37 of Set 7 | moerai
# Processing Record 38 of Set 7 | nanortalik
# Processing Record 39 of Set 7 | porbandar
# Processing Record 40 of Set 7 | newport
# Processing Record 41 of Set 7 | derbent
# Processing Record 42 of Set 7 | palmas
# Processing Record 43 of Set 7 | buchanan
# Processing Record 44 of Set 7 | san cristobal
# Processing Record 45 of Set 7 | kohlu
# Processing Record 46 of Set 7 | izberbash
# Processing Record 47 of Set 7 | sukumo
# Processing Record 48 of Set 7 | bang saphan
# Processing Record 49 of Set 7 | souillac
# Processing Record 50 of Set 7 | mahebourg
# Processing Record 1 of Set 8 | baker city
# Processing Record 2 of Set 8 | mayahi
# Processing Record 3 of Set 8 | agadez
# Processing Record 4 of Set 8 | talnakh
# Processing Record 5 of Set 8 | port lincoln
# Processing Record 6 of Set 8 | nishihara
# Processing Record 7 of Set 8 | natchitoches
# Processing Record 8 of Set 8 | hamza
# Processing Record 9 of Set 8 | talara
# Processing Record 10 of Set 8 | hamois
# Processing Record 11 of Set 8 | launceston
# Processing Record 12 of Set 8 | lincoln
# Processing Record 13 of Set 8 | comodoro rivadavia
# Processing Record 14 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 15 of Set 8 | tilichiki
# Processing Record 16 of Set 8 | okha
# Processing Record 17 of Set 8 | aksarayskiy
# Processing Record 18 of Set 8 | altamira
# Processing Record 19 of Set 8 | edgewater
# Processing Record 20 of Set 8 | kafanchan
# Processing Record 21 of Set 8 | bayan
# Processing Record 22 of Set 8 | spearfish
# Processing Record 23 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 8 | taoudenni
# Processing Record 25 of Set 8 | carauari
# Processing Record 26 of Set 8 | champerico
# Processing Record 27 of Set 8 | xining
# Processing Record 28 of Set 8 | caravelas
# Processing Record 29 of Set 8 | tahta
# Processing Record 30 of Set 8 | novobiryusinskiy
# Processing Record 31 of Set 8 | thunder bay
# Processing Record 32 of Set 8 | salamiyah
# Processing Record 33 of Set 8 | xifeng
# Processing Record 34 of Set 8 | hobyo
# Processing Record 35 of Set 8 | badiraguato
# Processing Record 36 of Set 8 | ponta do sol
# Processing Record 37 of Set 8 | whitehorse
# Processing Record 38 of Set 8 | rantepao
# Processing Record 39 of Set 8 | san juan
# Processing Record 40 of Set 8 | margate
# Processing Record 41 of Set 8 | san patricio
# Processing Record 42 of Set 8 | odweyne
# Processing Record 43 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 8 | cherskiy
# Processing Record 45 of Set 8 | burica
# City not found. Skipping...
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | mogoytuy
# Processing Record 48 of Set 8 | ust-koksa
# Processing Record 49 of Set 8 | inuvik
# Processing Record 50 of Set 8 | bathsheba
# Processing Record 1 of Set 9 | predivinsk
# Processing Record 2 of Set 9 | alenquer
# Processing Record 3 of Set 9 | shubarkuduk
# Processing Record 4 of Set 9 | anloga
# Processing Record 5 of Set 9 | campos novos
# Processing Record 6 of Set 9 | baft
# Processing Record 7 of Set 9 | inta
# Processing Record 8 of Set 9 | daru
# Processing Record 9 of Set 9 | mayumba
# Processing Record 10 of Set 9 | honningsvag
# Processing Record 11 of Set 9 | diego de almagro
# Processing Record 12 of Set 9 | rusape
# Processing Record 13 of Set 9 | dawei
# Processing Record 14 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 15 of Set 9 | mao
# Processing Record 16 of Set 9 | saint-paul
# Processing Record 17 of Set 9 | anadyr
# Processing Record 18 of Set 9 | izumo
# Processing Record 19 of Set 9 | kaeo
# Processing Record 20 of Set 9 | jinzhou
# Processing Record 21 of Set 9 | myanaung
# Processing Record 22 of Set 9 | boa vista
# Processing Record 23 of Set 9 | pasighat
# Processing Record 24 of Set 9 | acarau
# Processing Record 25 of Set 9 | roald
# Processing Record 26 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 9 | palafrugell
# Processing Record 28 of Set 9 | noyabrsk
# Processing Record 29 of Set 9 | losheim
# Processing Record 30 of Set 9 | saint-joseph
# Processing Record 31 of Set 9 | hualmay
# Processing Record 32 of Set 9 | salinopolis
# Processing Record 33 of Set 9 | mantua
# Processing Record 34 of Set 9 | olafsvik
# Processing Record 35 of Set 9 | hakui
# Processing Record 36 of Set 9 | lavrentiya
# Processing Record 37 of Set 9 | greytown
# Processing Record 38 of Set 9 | sur
# Processing Record 39 of Set 9 | tiangua
# Processing Record 40 of Set 9 | tiznit
# Processing Record 41 of Set 9 | marathon
# Processing Record 42 of Set 9 | lianzhou
# Processing Record 43 of Set 9 | svetlyy
# Processing Record 44 of Set 9 | yongan
# Processing Record 45 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 9 | araouane
# Processing Record 47 of Set 9 | labytnangi
# Processing Record 48 of Set 9 | segou
# Processing Record 49 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 9 | kemi
# Processing Record 1 of Set 10 | lundazi
# Processing Record 2 of Set 10 | puerto gaitan
# Processing Record 3 of Set 10 | la orilla
# Processing Record 4 of Set 10 | kindu
# Processing Record 5 of Set 10 | chetumal
# Processing Record 6 of Set 10 | ketchikan
# Processing Record 7 of Set 10 | sao gabriel da cachoeira
# Processing Record 8 of Set 10 | abha
# Processing Record 9 of Set 10 | torbay
# Processing Record 10 of Set 10 | nueve de julio
# Processing Record 11 of Set 10 | coihaique
# Processing Record 12 of Set 10 | dum duma
# Processing Record 13 of Set 10 | hailun
# Processing Record 14 of Set 10 | yian
# City not found. Skipping...
# Processing Record 15 of Set 10 | humen
# Processing Record 16 of Set 10 | puerto cabezas
# Processing Record 17 of Set 10 | monrovia
# Processing Record 18 of Set 10 | vagur
# Processing Record 19 of Set 10 | cayenne
# Processing Record 20 of Set 10 | martapura
# Processing Record 21 of Set 10 | gigmoto
# Processing Record 22 of Set 10 | miyako
# Processing Record 23 of Set 10 | richards bay
# Processing Record 24 of Set 10 | honiara
# Processing Record 25 of Set 10 | bonavista
# Processing Record 26 of Set 10 | linqu
# Processing Record 27 of Set 10 | shorapani
# Processing Record 28 of Set 10 | nsoko
# Processing Record 29 of Set 10 | lgov
# Processing Record 30 of Set 10 | sekoma
# Processing Record 31 of Set 10 | isangel
# Processing Record 32 of Set 10 | aberdeen
# Processing Record 33 of Set 10 | nimes
# Processing Record 34 of Set 10 | port hardy
# Processing Record 35 of Set 10 | la rioja
# Processing Record 36 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 10 | meghri
# Processing Record 38 of Set 10 | mwanza
# Processing Record 39 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 40 of Set 10 | borogontsy
# Processing Record 41 of Set 10 | novomikhaylovskiy
# Processing Record 42 of Set 10 | stromness
# Processing Record 43 of Set 10 | fredericksburg
# Processing Record 44 of Set 10 | juneau
# Processing Record 45 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 10 | puerto quijarro
# Processing Record 47 of Set 10 | wattegama
# Processing Record 48 of Set 10 | zhuhai
# Processing Record 49 of Set 10 | kapuskasing
# Processing Record 50 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 1 of Set 11 | yangjiang
# Processing Record 2 of Set 11 | zemio
# Processing Record 3 of Set 11 | los llanos de aridane
# Processing Record 4 of Set 11 | aykhal
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | nanchang
# Processing Record 7 of Set 11 | dilla
# Processing Record 8 of Set 11 | guaymas
# Processing Record 9 of Set 11 | severnyy-kospashskiy
# Processing Record 10 of Set 11 | kirakira
# Processing Record 11 of Set 11 | chumikan
# Processing Record 12 of Set 11 | paranavai
# Processing Record 13 of Set 11 | mahon
# Processing Record 14 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 11 | binzhou
# Processing Record 16 of Set 11 | kulhudhuffushi
# Processing Record 17 of Set 11 | narino
# Processing Record 18 of Set 11 | pokrovsk
# Processing Record 19 of Set 11 | marly
# Processing Record 20 of Set 11 | llata
# Processing Record 21 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 11 | tashigang
# Processing Record 23 of Set 11 | mlonggo
# Processing Record 24 of Set 11 | wajid
# Processing Record 25 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 11 | portree
# Processing Record 27 of Set 11 | gryfice
# Processing Record 28 of Set 11 | rudbar
# Processing Record 29 of Set 11 | yurimaguas
# Processing Record 30 of Set 11 | bud
# Processing Record 31 of Set 11 | blagoyevo
# Processing Record 32 of Set 11 | bandarbeyla
# Processing Record 33 of Set 11 | ojinaga
# Processing Record 34 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | skibbereen
# Processing Record 36 of Set 11 | khuzdar
# Processing Record 37 of Set 11 | nyurba
# Processing Record 38 of Set 11 | haradok
# Processing Record 39 of Set 11 | sande
# Processing Record 40 of Set 11 | pishva
# Processing Record 41 of Set 11 | waw
# Processing Record 42 of Set 11 | chase
# Processing Record 43 of Set 11 | newala
# Processing Record 44 of Set 11 | flinders
# Processing Record 45 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 11 | coahuayana
# Processing Record 48 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | roebourne
# Processing Record 50 of Set 11 | luanda
# Processing Record 1 of Set 12 | puerto penasco
# Processing Record 2 of Set 12 | miracema do tocantins
# Processing Record 3 of Set 12 | porosozero
# Processing Record 4 of Set 12 | tshane
# Processing Record 5 of Set 12 | birao
# Processing Record 6 of Set 12 | haines junction
# Processing Record 7 of Set 12 | tres arroyos
# Processing Record 8 of Set 12 | kokomo
# Processing Record 9 of Set 12 | guider
# Processing Record 10 of Set 12 | ushtobe
# Processing Record 11 of Set 12 | tadine
# Processing Record 12 of Set 12 | maple valley
# Processing Record 13 of Set 12 | urengoy
# Processing Record 14 of Set 12 | bowen
# Processing Record 15 of Set 12 | sungairaya
# Processing Record 16 of Set 12 | rio pardo de minas
# Processing Record 17 of Set 12 | shiyan
# Processing Record 18 of Set 12 | pemangkat
# Processing Record 19 of Set 12 | shache
# Processing Record 20 of Set 12 | karratha
# Processing Record 21 of Set 12 | tucuman
# Processing Record 22 of Set 12 | cotonou
# Processing Record 23 of Set 12 | suyan
# Processing Record 24 of Set 12 | yei
# Processing Record 25 of Set 12 | camabatela
# Processing Record 26 of Set 12 | greenfield
# Processing Record 27 of Set 12 | maiduguri
# Processing Record 28 of Set 12 | swellendam
# Processing Record 29 of Set 12 | kovdor
# Processing Record 30 of Set 12 | xiaoshi
# Processing Record 31 of Set 12 | karatau
# Processing Record 32 of Set 12 | hay river
# Processing Record 33 of Set 12 | tocaima
# Processing Record 34 of Set 12 | jining
# Processing Record 35 of Set 12 | kalmunai
# Processing Record 36 of Set 12 | nazas
# Processing Record 37 of Set 12 | caala
# Processing Record 38 of Set 12 | poli
# Processing Record 39 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 12 | olinda
# Processing Record 41 of Set 12 | springbok
# Processing Record 42 of Set 12 | najran
# Processing Record 43 of Set 12 | oliveira dos brejinhos
# Processing Record 44 of Set 12 | montepuez
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | ryotsu
# Processing Record 47 of Set 12 | trinidad
# Processing Record 48 of Set 12 | sabha
# Processing Record 49 of Set 12 | pringsewu
# Processing Record 50 of Set 12 | srednekolymsk
# Processing Record 1 of Set 13 | alexandria
# Processing Record 2 of Set 13 | channel-port aux basques
# Processing Record 3 of Set 13 | envira
# Processing Record 4 of Set 13 | ixtapa
# Processing Record 5 of Set 13 | taltal
# Processing Record 6 of Set 13 | baruun-urt
# Processing Record 7 of Set 13 | kieta
# Processing Record 8 of Set 13 | kamenka
# Processing Record 9 of Set 13 | leh
# Processing Record 10 of Set 13 | charters towers
# Processing Record 11 of Set 13 | valparaiso
# Processing Record 12 of Set 13 | garissa
# Processing Record 13 of Set 13 | vila franca do campo
# Processing Record 14 of Set 13 | laguna
# Processing Record 15 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 16 of Set 13 | ponta delgada
# Processing Record 17 of Set 13 | lemoore
# Processing Record 18 of Set 13 | jiayuguan
# Processing Record 19 of Set 13 | tazovskiy
# Processing Record 20 of Set 13 | seabra
# Processing Record 21 of Set 13 | kavaratti
# Processing Record 22 of Set 13 | hanford
# Processing Record 23 of Set 13 | muli
# Processing Record 24 of Set 13 | puerto ayacucho
# Processing Record 25 of Set 13 | suntar
# Processing Record 26 of Set 13 | porto velho
# Processing Record 27 of Set 13 | nizhniy odes
# Processing Record 28 of Set 13 | kutum
# Processing Record 29 of Set 13 | erdenet
# Processing Record 30 of Set 13 | morondava
# Processing Record 31 of Set 13 | ocotal
# Processing Record 32 of Set 13 | latung
# Processing Record 33 of Set 13 | dharchula
# Processing Record 34 of Set 13 | saint-augustin
# Processing Record 35 of Set 13 | thuro
# City not found. Skipping...
# Processing Record 36 of Set 13 | quesnel
# Processing Record 37 of Set 13 | den helder
# Processing Record 38 of Set 13 | kosa
# Processing Record 39 of Set 13 | nikolsk
# Processing Record 40 of Set 13 | zhigansk
# Processing Record 41 of Set 13 | manavalakurichi
# Processing Record 42 of Set 13 | sibolga
# Processing Record 43 of Set 13 | kizema
# Processing Record 44 of Set 13 | tuxpan
# Processing Record 45 of Set 13 | constitucion
# Processing Record 46 of Set 13 | biloela
# Processing Record 47 of Set 13 | matagami
# Processing Record 48 of Set 13 | akhisar
# Processing Record 49 of Set 13 | tezu
# Processing Record 50 of Set 13 | mitu
# Processing Record 1 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 14 | nuuk
# Processing Record 3 of Set 14 | chistogorskiy
# Processing Record 4 of Set 14 | lingao
# Processing Record 5 of Set 14 | lambarene
# Processing Record 6 of Set 14 | saleilua
# City not found. Skipping...
# Processing Record 7 of Set 14 | lusambo
# Processing Record 8 of Set 14 | port blair
# Processing Record 9 of Set 14 | fredericton
# Processing Record 10 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 14 | willowmore
# Processing Record 12 of Set 14 | presidencia roque saenz pena
# Processing Record 13 of Set 14 | kenai
# Processing Record 14 of Set 14 | sokoni
# Processing Record 15 of Set 14 | bougouni
# Processing Record 16 of Set 14 | bandar
# Processing Record 17 of Set 14 | benjamin constant
# Processing Record 18 of Set 14 | waipawa
# Processing Record 19 of Set 14 | carballo
# Processing Record 20 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 14 | benghazi
# Processing Record 22 of Set 14 | fenoarivo
# Processing Record 23 of Set 14 | hofn
# Processing Record 24 of Set 14 | muzhi
# Processing Record 25 of Set 14 | edd
# Processing Record 26 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 27 of Set 14 | snezhnogorsk
# Processing Record 28 of Set 14 | phalaborwa
# Processing Record 29 of Set 14 | evensk
# Processing Record 30 of Set 14 | tomarovka
# Processing Record 31 of Set 14 | kinwat
# Processing Record 32 of Set 14 | napier
# Processing Record 33 of Set 14 | gatton
# Processing Record 34 of Set 14 | half moon bay
# Processing Record 35 of Set 14 | bell ville
# Processing Record 36 of Set 14 | outlook
# Processing Record 37 of Set 14 | brae
# Processing Record 38 of Set 14 | kandrian
# Processing Record 39 of Set 14 | penzance
# Processing Record 40 of Set 14 | tumba
# Processing Record 41 of Set 14 | kouroussa
# Processing Record 42 of Set 14 | la suiza
# Processing Record 43 of Set 14 | knysna
# Processing Record 44 of Set 14 | gat
# Processing Record 45 of Set 14 | ternate
# Processing Record 46 of Set 14 | guaiba
# Processing Record 47 of Set 14 | oleksandrivka
# Processing Record 48 of Set 14 | palmer
# Processing Record 49 of Set 14 | taunggyi
# Processing Record 50 of Set 14 | clemson
# Processing Record 1 of Set 15 | tayga
# Processing Record 2 of Set 15 | chifeng
# Processing Record 3 of Set 15 | cumra
# Processing Record 4 of Set 15 | sherlovaya gora
# Processing Record 5 of Set 15 | oriximina
# Processing Record 6 of Set 15 | san jeronimo
# Processing Record 7 of Set 15 | maniwaki
# Processing Record 8 of Set 15 | jumla
# Processing Record 9 of Set 15 | makakilo city
# Processing Record 10 of Set 15 | shangqiu
# Processing Record 11 of Set 15 | barcelos
# Processing Record 12 of Set 15 | eenhana
# Processing Record 13 of Set 15 | pindobacu
# Processing Record 14 of Set 15 | port macquarie
# Processing Record 15 of Set 15 | darnah
# Processing Record 16 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 17 of Set 15 | isla vista
# Processing Record 18 of Set 15 | bani walid
# Processing Record 19 of Set 15 | petrivka
# Processing Record 20 of Set 15 | jalu
# Processing Record 21 of Set 15 | catamarca
# Processing Record 22 of Set 15 | karonga
# Processing Record 23 of Set 15 | marzuq
# Processing Record 24 of Set 15 | koslan
# Processing Record 25 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 15 | la grande
# Processing Record 27 of Set 15 | hamilton
# Processing Record 28 of Set 15 | singkang
# Processing Record 29 of Set 15 | pahrump
# Processing Record 30 of Set 15 | mareeba
# Processing Record 31 of Set 15 | fort pierce
# Processing Record 32 of Set 15 | ceyhan
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | namibe
# Processing Record 35 of Set 15 | diffa
# Processing Record 36 of Set 15 | emerald
# Processing Record 37 of Set 15 | pacifica
# Processing Record 38 of Set 15 | ornskoldsvik
# Processing Record 39 of Set 15 | ilo
# Processing Record 40 of Set 15 | erenhot
# Processing Record 41 of Set 15 | port-cartier
# Processing Record 42 of Set 15 | pecos
# Processing Record 43 of Set 15 | madimba
# Processing Record 44 of Set 15 | dukat
# Processing Record 45 of Set 15 | verkhnyaya inta
# Processing Record 46 of Set 15 | esna
# Processing Record 47 of Set 15 | asfi
# Processing Record 48 of Set 15 | valdivia
# Processing Record 49 of Set 15 | batagay
# Processing Record 50 of Set 15 | yasnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0  Busselton -33.6500  115.3333     54.88        81          16        9.53
# 1   Ishigaki  24.3448  124.1572     69.93        73         100        8.05
# 2     Hasaki  35.7333  140.8333     43.20        61         100        8.81
# 3      Jhalu  29.3500   78.2500     79.32        18           0        2.59
# 4      Pisco -13.7000  -76.2167     71.65        68           0       24.16
# 5    Ushuaia -54.8000  -68.3000     44.26        57          20        8.05
# 6      Sitka  57.0531 -135.3300     44.49        59          83        4.88
# 7    Jijiang  29.2906  106.2542     56.37        92         100        3.38
# 8  Fairbanks  64.8378 -147.7164     32.23        34           0        9.22
# 9      Bluff -46.6000  168.3333     40.80        79          97        8.46

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
